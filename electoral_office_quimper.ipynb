# %% [markdown]
# ## Study context
#
# During the municipal election campaign, a party seeks to know how many documents per electoral district it has to prepare per polling station. This is to optimize the preparation for distribution by parcel carriers. The city concerned is Quimper.

# %%
import json
import geopy.geocoders
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
geopy.geocoders.options.default_user_agent = 'my_app/1'
import folium 
import pandas as pd
import requests

# %%
# data about the geographical perimeters of electoral offices

url_borough = 'https://www.data.gouv.fr/fr/datasets/r/2d84335f-1441-458e-9a7d-e356b81192aa'
elec_office= requests.get(url_borough).json()

# %%
#coordinates of Quimper

address = 'Quimper'

geolocator = Nominatim()
locationq = geolocator.geocode(address)
latitudeq = locationq.latitude
longitudeq = locationq.longitude
print('The geograpical coordinate of Quimper City are {}, {}.'.format(latitudeq, longitudeq))
# Out:
# The geograpical coordinate of Quimper City are 47.9960325, -4.1024782.

# %%
# show Quimper and its several electoral offices
quimper_map = folium.Map(location=[latitudeq,longitudeq ], zoom_start=12)
quimper_map .add_child(folium.GeoJson(elec_office))

quimper_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# data about all adress of Quimper
adress_url = 'https://www.data.gouv.fr/fr/datasets/r/5ff3c371-d1bd-4b5e-83e5-50323dd0ca56'
adress= requests.get(adress_url).json()['features']

# %%
liste_adress = []
liste = []
for a in adress : 
    #only Quimper's adresses
    if a['properties']['IDCOMM'] == '290232' : 
        liste.append(a['properties']['IDCOMM'])
        liste.append(a['properties']['ADR_OBS'])
        liste.append(a['geometry']['coordinates'])
        liste_adress.append(liste)
        liste =[]

df_adress = pd.DataFrame(liste_adress)
df_adress.columns=['Id_city','Adress','coordinate']
df_adress.head()
# Out:
#   Id_city                      Adress  \
# 0  290232  8 RUE AMIRAL JULIEN COSMAO
# 1  290232   15 ALLEE MATHIAS LE LOUET
# 2  290232          15 RUE DE LOCRONAN
# 3  290232     20 CHEMIN DE KERLIVIDIC
# 4  290232     91 CHEMIN DE KERLIVIDIC
#
#                                  coordinate
# 0    [-4.097744878879205, 48.0073865140059]
# 1   [-4.127051366570884, 48.00509412450984]
# 2   [-4.108609193861332, 47.99790696909011]
# 3  [-4.110064788799618, 48.029439632908826]
# 4   [-4.117161885805333, 48.02676951721479]

# %%
df_adress.shape
# Out:
# (25548, 3)

# %%
# build dataframe with electoral offices
listeo = []
listeoffice = []
for b in elec_office['features'] : 
    listeo.append(b['properties']['ADRESSE'])
    listeo.append(b['properties']['LIEU_VOTE'])
    listeo.append(b['properties']['BUREAUX'])
    listeo.append(b['geometry']['coordinates'])
    listeoffice.append(listeo)
    listeo = []
df_office = pd.DataFrame(listeoffice)
df_office.columns = ['adress','name','electoral office','limit']
df_office.head()
# Out:
#                              adress                              name  \
# 0              53 rue des Cerisiers    Ecole Elementaire de Kervilien
# 1          107 route de Pont-l'Abbé    Immeuble communal de Penanguer
# 2  114 bis avenue de Kergoat Ar Lez     Ecole Primaire Kergoat al Lez
# 3                 6 place du Cosmos  Ecole Primaire Pauline Kergomard
# 4       14 rue des Trois Le Guennec       Ecole Primaire de Penanguer
#
#    electoral office                                              limit
# 0                13  [[[[-4.118259889941478, 47.98039688374357], [-...
# 1                12  [[[[-4.120908265173999, 47.98075363864825], [-...
# 2                23  [[[[-4.083332382946192, 47.991199413091614], [...
# 3                26  [[[[-4.071659439189485, 47.993605349581706], [...
# 4                11  [[[[-4.118587205153393, 47.98975127084124], [-...

# %%
# sort by number of electoral office
df_office = df_office.sort_values(by='electoral office')
df_office = df_office.reset_index()
df_office = df_office.drop(['index'],axis=1)
df_office.head()
# Out:
#                   adress                               name  electoral office  \
# 0         18 bis rue Vis   Ecole Primaire Ferdinand Buisson                 1
# 1         18 bis rue Vis   Ecole Primaire Ferdinand Buisson                 2
# 2  47 chemin de Prateyer  Maison de quartier du Moulin Vert                 3
# 3  47 rue du Moulin Vert       Ecole Primaire Léon Goraguer                 4
# 4  47 rue du Moulin Vert       Ecole Primaire Léon Goraguer                 5
#
#                                                limit
# 0  [[[[-4.108673293265551, 47.99501961609982], [-...
# 1  [[[[-4.112517294922924, 47.992208843904606], [...
# 2  [[[[-4.110138603043166, 48.00086973406141], [-...
# 3  [[[[-4.105270014879253, 48.00233931160333], [-...
# 4  [[[[-4.140739902820359, 48.01938027552455], [-...

# %%
pip install shapely
# Out:
# Collecting shapely
#   Downloading Shapely-1.7.0-cp37-cp37m-macosx_10_9_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 1.7 MB/s eta 0:00:01     |████▏                           | 215 kB 1.7 MB/s eta 0:00:01
# Installing collected packages: shapely
# Successfully installed shapely-1.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from shapely.geometry import Point, Polygon

# %%
# build dataframe with the center of electoral office perimeter to show on the map
centre = []
for p in range(df_office.shape[0]) :
            coords = df_office.loc[p,'limit'][0][0]
            poly = Polygon(coords)
            c = poly.centroid.coords
            centre.append(c)
df_centre = pd.DataFrame(centre)
df_centre.head()
df_centre=pd.concat([df_centre,df_office[['name','electoral office']]],axis=1)
df_centre.columns=['coordinate centre','name','electoral office']

# %%
df_centre.head()
# Out:
#                           coordinate centre  \
# 0  (-4.1123023310345035, 47.99162418855593)
# 1   (-4.114556622282839, 47.99406642233797)
# 2  (-4.115403671361115, 47.999232833967355)
# 3   (-4.111523345415905, 48.00443139438004)
# 4   (-4.129110175001721, 48.01080187532915)
#
#                                 name  electoral office
# 0   Ecole Primaire Ferdinand Buisson                 1
# 1   Ecole Primaire Ferdinand Buisson                 2
# 2  Maison de quartier du Moulin Vert                 3
# 3       Ecole Primaire Léon Goraguer                 4
# 4       Ecole Primaire Léon Goraguer                 5

# %%
# show the name of electoral offices
for coordinate,name, nb_office in zip(df_centre['coordinate centre'],
                             df_centre['name'],df_centre['electoral office']):
        lat = coordinate[1]
        lng = coordinate[0]
        label = folium.Popup(str(nb_office) + '-' + name, parse_html = True)
        folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'green',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.6,
        parse_html = False).add_to(quimper_map) 
quimper_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# function to assign each adress to a electoral office
def office():
    liste = []
    resume = []
    compte=0
    for j in range(df_adress.shape[0]):
        p = Point(df_adress.loc[j,'coordinate'])

# detection in a Polygon
        for u in range(df_office.shape[0]) :
            coords = df_office.loc[u,'limit'][0][0]
            poly = Polygon(coords)
            if p.within(poly) == True: 
                liste.append(df_adress.loc[j,'Adress'])
                liste.append(df_adress.loc[j,'coordinate'])
                liste.append(df_office.loc[u,'electoral office'])
                resume.append(liste)
                liste = []
                break
    df_liste=pd.DataFrame(resume)
    df_liste.columns=['adress','coordinate','electoral office']
   
    return df_liste

# %%
# build the dataframe with the function office
df_adress_office = office()

# %%
df_adress_office.head()
# Out:
#                        adress                                coordinate  \
# 0  8 RUE AMIRAL JULIEN COSMAO    [-4.097744878879205, 48.0073865140059]
# 1   15 ALLEE MATHIAS LE LOUET   [-4.127051366570884, 48.00509412450984]
# 2          15 RUE DE LOCRONAN   [-4.108609193861332, 47.99790696909011]
# 3     20 CHEMIN DE KERLIVIDIC  [-4.110064788799618, 48.029439632908826]
# 4     91 CHEMIN DE KERLIVIDIC   [-4.117161885805333, 48.02676951721479]
#
#    electoral office
# 0                41
# 1                 6
# 2                40
# 3                43
# 4                43

# %%
# calculation of adresses numbers per electoral offices
office_count=df_adress_office.groupby('electoral office').count()

# %%
# clean the dataframe
office_count = office_count['adress']
office_count = office_count.reset_index()
office_count = office_count.rename(columns={'adress':'nb house'})
office_count ['electoral office'] = office_count['electoral office'].astype('int64')

# %%
# merge with the dataframe df_office 
office_count = pd.merge(office_count,df_office[['electoral office','adress','name']], on ='electoral office')
office_count.head()
# Out:
#    electoral office  nb house                 adress  \
# 0                 1       453         18 bis rue Vis
# 1                 2       298         18 bis rue Vis
# 2                 3       510  47 chemin de Prateyer
# 3                 4       382  47 rue du Moulin Vert
# 4                 5       564  47 rue du Moulin Vert
#
#                                 name
# 0   Ecole Primaire Ferdinand Buisson
# 1   Ecole Primaire Ferdinand Buisson
# 2  Maison de quartier du Moulin Vert
# 3       Ecole Primaire Léon Goraguer
# 4       Ecole Primaire Léon Goraguer

# %%
# test of a electoral office : 

df_adress_office49 = df_adress_office[df_adress_office['electoral office'] == 49]

# %%
# show the adresses classified to the electoral office 2 
quimper_map = folium.Map(location=[latitudeq,longitudeq ], zoom_start=12)
quimper_map .add_child(folium.GeoJson(elec_office))
for coordinate,name, nb_office in zip(df_centre['coordinate centre'],
                             df_centre['name'],df_centre['electoral office']):
        lat = coordinate[1]
        lng = coordinate[0]
        label = folium.Popup(str(nb_office) + '-' + name, parse_html = True)
        folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'green',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.6,
        parse_html = False).add_to(quimper_map) 
    
for coordinate, label in zip(df_adress_office49['coordinate'],
                             df_adress_office49['adress']):
        lat = coordinate[1]
        lng = coordinate[0]
        label = folium.Popup(label, parse_html = True)
        folium.CircleMarker(
        [lat, lng],
        radius = 1,
        popup = label,
        color = 'pink',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.6,
        parse_html = False).add_to(quimper_map) 
quimper_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We observe only pink markers in an electoral office perimeter. When we check the electoral office marker, it is the electoral office 49.

# %% [markdown]
# Calculation hypothesis :
#
# sources :
# * http://reseaux-chaleur.cerema.fr/wp-content/uploads/2008_Extrait_etude_CDC_Boucle_locale_optique___donnees_sur_le_parc_immobilier_francais.pdf
#
# * http://www.journaldunet.com/management/ville/quimper/ville-29232/immobilier
#
# 47% of Quimper's dwellings are houses, 53% are apartments.
# in 2009 Quimper had 35984 dwellings, there is a growth of 4000 dwellings every 10 years.
# 85% of buildings have 6 appartments, 13% of buildings have 16 appartments, 2% of buildings have 32 appartments.

# %%
# estimated number of dwellings in 2020
dwelling=round(35984+4000*11/10)
print('estimated number of dwellings in 2020: ',dwelling )

# estimated number of adresses representing houses : 
hose =round(dwelling*0.47)
print('houses en 2020: ',house)

# houses percentage per adress : 

houseperc = house/df_adress.shape[0]
print('houses percentage per adress:', houseperc )

#estimated number of adresses representing building : 
building = df_adress.shape[0] - house
print('buildings en 2020 : ',building)

# average appartment numbers per building

appart=round((dwelling-house)/building)
print("average appartment numbers per building:" ,appart)
# Out:
# estimated number of dwellings in 2020:  40384
# houses en 2020:  18980
# houses percentage per adress: 0.7429152966964145
# buildings en 2020 :  6568
# average appartment numbers per building: 3

# %% [markdown]
# When we apply the repartition of buildings with the number of appartments, we get to many dwellings.
# So we choose to adapt the repartition like this :
# 98% of buildings have 3 appartments, 2% of them have 16 appartments.

# %%
# calculation of numbers of mailboxes
office_count['nb house'] = round(office_count['nb house']*(0.74+0.26*(0.98*3+0.02*16)))
office_count = office_count.rename(columns={'nb house':'nb mailboxes'})

# %%
office_count
# Out:
#     electoral office  nb mailboxes  \
# 0                  1         719.0
# 1                  2         473.0
# 2                  3         810.0
# 3                  4         606.0
# 4                  5         895.0
# 5                  6        1014.0
# 6                  7         891.0
# 7                  8        1041.0
# 8                  9         643.0
# 9                 10         695.0
# 10                11         829.0
# 11                12         683.0
# 12                13         867.0
# 13                14         956.0
# 14                15         816.0
# 15                16         175.0
# 16                17         332.0
# 17                18         168.0
# 18                19         824.0
# 19                20         711.0
# 20                21         759.0
# 21                22         686.0
# 22                23         886.0
# 23                24        1083.0
# 24                25         783.0
# 25                26         930.0
# 26                27        1143.0
# 27                28         780.0
# 28                29        1373.0
# 29                30        1438.0
# 30                31        1005.0
# 31                32         629.0
# 32                33         462.0
# 33                34         743.0
# 34                35         721.0
# 35                36        1068.0
# 36                37         791.0
# 37                38         681.0
# 38                39        1121.0
# 39                40         954.0
# 40                41         833.0
# 41                42         497.0
# 42                43         964.0
# 43                44        1103.0
# 44                45         870.0
# 45                46         981.0
# 46                47        1240.0
# 47                48         853.0
# 48                49        1019.0
#
#                                          adress  \
# 0                                18 bis rue Vis
# 1                                18 bis rue Vis
# 2                         47 chemin de Prateyer
# 3                         47 rue du Moulin Vert
# 4                         47 rue du Moulin Vert
# 5                         47 rue du Moulin Vert
# 6                  75 bis rue de la Terre Noire
# 7                  75 bis rue de la Terre Noire
# 8                            2 place de Penhars
# 9                            2 place de Penhars
# 10                  14 rue des Trois Le Guennec
# 11                     107 route de Pont-l'Abbé
# 12                         53 rue des Cerisiers
# 13                         53 rue des Cerisiers
# 14                       2, chemin de Kerlagatu
# 15                      3 boulevard de Bretagne
# 16                      3 boulevard de Bretagne
# 17                               17 rue du Léon
# 18                           10, rue de Kerogan
# 19                      44 place Saint Corentin
# 20  3 esplanade Famille Gabaï / rue Jean Jaurès
# 21       Rue Louise Michel / rue Saint Pol Roux
# 22             114 bis avenue de Kergoat Ar Lez
# 23                          87 avenue Léon Blum
# 24                          87 avenue Léon Blum
# 25                            6 place du Cosmos
# 26                            6 place du Cosmos
# 27                            6 place du Cosmos
# 28                         11 rue de Saint Alor
# 29                         11 rue de Saint Alor
# 30                13-15 place Victor Schoelcher
# 31                13-15 place Victor Schoelcher
# 32                   11 place Victor Schoelcher
# 33                             2 rue Emile Zola
# 34                        4 rue Alfred de Vigny
# 35                        4 rue Alfred de Vigny
# 36                          6 place Guy Ropartz
# 37                          6 place Guy Ropartz
# 38                      44 place Saint Corentin
# 39          1-3-5 Esplanade François Mitterrand
# 40                 52 avenue de la France Libre
# 41                 52 avenue de la France Libre
# 42                 52 avenue de la France Libre
# 43                 52 avenue de la France Libre
# 44                          30 rue Henri Dunant
# 45                          30 rue Henri Dunant
# 46                          30 rue Henri Dunant
# 47                          25 rue de Kermoguer
# 48                          152 la Voie Romaine
#
#                                     name
# 0       Ecole Primaire Ferdinand Buisson
# 1       Ecole Primaire Ferdinand Buisson
# 2      Maison de quartier du Moulin Vert
# 3           Ecole Primaire Léon Goraguer
# 4           Ecole Primaire Léon Goraguer
# 5           Ecole Primaire Léon Goraguer
# 6      Ecole Elémentaire Yves Le Manchec
# 7      Ecole Elémentaire Yves Le Manchec
# 8   Ecole Maternelle du bourg de Penhars
# 9   Ecole Maternelle du bourg de Penhars
# 10           Ecole Primaire de Penanguer
# 11        Immeuble communal de Penanguer
# 12        Ecole Elementaire de Kervilien
# 13        Ecole Elementaire de Kervilien
# 14        Maison de quartier du Moustoir
# 15        Ecole Maternelle Paul Langevin
# 16        Ecole Maternelle Paul Langevin
# 17      Maison de Quartier de Prat-Maria
# 18          Centre de Loisirs de Kerogan
# 19                         Mairie-Centre
# 20                             Ti ar Vro
# 21                   Salle Denise Larzul
# 22         Ecole Primaire Kergoat al Lez
# 23          Mairie annexe de Ergué-Armel
# 24          Mairie annexe de Ergué-Armel
# 25      Ecole Primaire Pauline Kergomard
# 26      Ecole Primaire Pauline Kergomard
# 27      Ecole Primaire Pauline Kergomard
# 28          Ecole Maternelle du Quinquis
# 29          Ecole Maternelle du Quinquis
# 30        Ecole Primaire Edmond Michelet
# 31        Ecole Primaire Edmond Michelet
# 32                      Maison du Braden
# 33             Ecole Primaire Emile Zola
# 34            Ecole Primaire Victor Hugo
# 35            Ecole Primaire Victor Hugo
# 36        Ecole Maternelle Paul Grimault
# 37        Ecole Maternelle Paul Grimault
# 38                         Mairie-Centre
# 39                 Espace Grands Projets
# 40    Ecole Primaire Frédéric Le Guyader
# 41    Ecole Primaire Frédéric Le Guyader
# 42    Ecole Primaire Frédéric Le Guyader
# 43    Ecole Primaire Frédéric Le Guyader
# 44        Ecole Primaire Jacques Prévert
# 45        Ecole Primaire Jacques Prévert
# 46        Ecole Primaire Jacques Prévert
# 47                  Ecole Primaire Diwan
# 48             Maison rurale de Kernilis

# %%
# we check that our numbers of mailboxes has the same order of magnitude as the estimated number of dwellings
office_count['nb mailboxes'] .sum()
# Out:
# 40544.0

# %%
# export the data as excel
office_count.to_excel('nbreparbureau.xlsx', engine='xlsxwriter')

# %% [markdown]
# ## Results and conclusion
#
# From geographical data on the perimeters of the various electoral offices and all the addresses in Quimper, we were able to determine the number of existing addresses per electoral office.
# The purpose of this study is to define the number of ballots needed for the electoral cocanditates. It was therefore necessary to estimate the number of houses and buildings. From the number of addresses we were able to give a first estimate of the number of mailboxes per electoral office.
#
# Of course, the basic data (percentage of houses, number of dwellings, etc.) used are average estimates. It is very likely that the distribution of houses and buildings is not the same in each electoral office perimeter. Similarly, the size of the buildings and therefore the number of apartments per building may vary. This is therefore an initial estimate of the need for ballot papers. These figures will have to be refined subsequently by field experience or a new source of data not currently available.
